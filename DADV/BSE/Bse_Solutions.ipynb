# %% [markdown]
# # TASK-1

# %% [markdown]
# # Identify the top 10 gainers (%) across groups over the last one month, 3 months,  6 months, one year, 2 years, 3 years and 5 years period.
# #Note: The gain is the closing price on the last day of the period, divided by the closing price on the first day of the period, minus 1

# %% [markdown]
# # 1.Identify the top 10 gainers (%) across groups over the last one month

# %%
import pandas as pd
import os
import numpy as np
from itertools import combinations
from matplotlib import pyplot as plt
import pdfcrowd

# %%
data = {}
for root,dirs,files in os.walk(os.curdir):
    for file in files:
        if file.endswith('.csv') and file.startswith("5"):
            name = os.path.splitext(file)[0]
            df = pd.read_csv(file, thousands = ",")
            df = df[0 : 30]
            df["Date"] = pd.to_datetime(df["Date"])
            df.sort_values(by = "Date", inplace = True)
            
            try :
                start = df["Close"].iloc[0]
            except Exception as e:
                start = df["Close Price"].iloc[0]
            
            try :
                end = df["Close"].iloc[-1]
            except Exception as e:
                end = df["Close Price"].iloc[-1]
            gain = (end/start) - 1
            data[name] = gain
            
df = pd.DataFrame(data.items(), columns = ["security", "gain"])
df.sort_values(by = "gain", inplace = True, ascending = False)
df.head(10)
# Out:
#    security      gain
# 68   500143  1.525263
# 6    500013  1.491991
# 73   500151  1.298876
# 7    500014  0.902174
# 82   500170  0.840789
# 76   500160  0.804878
# 91   500185  0.740883
# 54   500113  0.728288
# 24   500048  0.557455
# 5    500012  0.521212

# %% [markdown]
# # 2.identify the top 10 gainers (%) across groups over the last 3 months.

# %%
data = {}
for root,dirs,files in os.walk(os.curdir):
    for file in files:
        if file.endswith('.csv') and file.startswith("5"):
            name = os.path.splitext(file)[0]
            df = pd.read_csv(file, thousands = ",")
            df = df[0 : 90]
            df["Date"] = pd.to_datetime(df["Date"])
            df.sort_values(by = "Date", inplace = True)
            
            try :
                start = df["Close"].iloc[0]
            except Exception as e:
                start = df["Close Price"].iloc[0]
            
            try :
                end = df["Close"].iloc[-1]
            except Exception as e:
                end = df["Close Price"].iloc[-1]
            gain = (end/start) - 1
            data[name] = gain
            
df = pd.DataFrame(data.items(), columns = ["security", "gain"])
df.sort_values(by = "gain", inplace = True, ascending = False)
df.head(10)
# Out:
#    security      gain
# 76   500160  2.502959
# 41   500093  1.568859
# 6    500013  1.346983
# 26   500052  1.269868
# 73   500151  1.100616
# 93   500187  0.783169
# 12   500028  0.674497
# 99   500199  0.672655
# 82   500170  0.665476
# 54   500113  0.664277

# %% [markdown]
# # 3. Identify the top 10 gainers (%) across groups over the last 6 months period.

# %%
data = {}
for root,dirs,files in os.walk(os.curdir):
    for file in files:
        if file.endswith('.csv') and file.startswith("5"):
            name = os.path.splitext(file)[0]
            df = pd.read_csv(file, thousands = ",")
            #0 to 90 denotes as 6 months of period.
            df = df[0 : 180]
            df["Date"] = pd.to_datetime(df["Date"])
            #it sorts the values as per date from last, so that we can take top 10 using head()
            df.sort_values(by = "Date", inplace = True)
            
            #here we take the closing price as value.
            try :
                start = df["Close"].iloc[0]
            except Exception as e:
                start = df["Close Price"].iloc[0]
            
            try :
                end = df["Close"].iloc[-1]
            except Exception as e:
                end = df["Close Price"].iloc[-1]
            gain = (end/start) - 1
            data[name] = gain
            
df = pd.DataFrame(data.items(), columns = ["security", "gain"])
df.sort_values(by = "gain", inplace = True, ascending = False)
df.head(10)
# Out:
#    security      gain
# 41   500093  4.332555
# 67   500136  3.153982
# 76   500160  3.082759
# 45   500102  2.888889
# 33   500078  2.525000
# 26   500052  2.406211
# 99   500199  2.313258
# 73   500151  1.742627
# 52   500111  1.670306
# 54   500113  1.594041

# %% [markdown]
# # 4. Identify the top 10 gainers (%) across groups over the last 1 year period.

# %%
data = {}
for root,dirs,files in os.walk(os.curdir):
    for file in files:
        if file.endswith('.csv') and file.startswith("5"):
            name = os.path.splitext(file)[0]
            df = pd.read_csv(file, thousands = ",")
            df = df[0 : 365]
            df["Date"] = pd.to_datetime(df["Date"])
            df.sort_values(by = "Date", inplace = True)
            
            try :
                start = df["Close"].iloc[0]
            except Exception as e:
                start = df["Close Price"].iloc[0]
            
            try :
                end = df["Close"].iloc[-1]
            except Exception as e:
                end = df["Close Price"].iloc[-1]
            gain = (end/start) - 1
            data[name] = gain

df = pd.DataFrame(data.items(), columns = ["security", "gain"])
df.sort_values(by = "gain", inplace = True, ascending = False)
df.head(10)
# Out:
#    security      gain
# 67   500136  3.153982
# 33   500078  1.761964
# 59   500120  1.586822
# 41   500093  1.176190
# 6    500013  1.160714
# 26   500052  1.107610
# 62   500125  1.043554
# 66   500135  0.987688
# 61   500124  0.965994
# 74   500153  0.806313

# %% [markdown]
# # 5. Identify the top 10 gainers (%) across groups over the last 2 years period.

# %%
data = {}
for root,dirs,files in os.walk(os.curdir):
    for file in files:
        if file.endswith('.csv') and file.startswith("5"):
            name = os.path.splitext(file)[0]
            df = pd.read_csv(file, thousands = ",")
            df = df[0 : 730]
            df["Date"] = pd.to_datetime(df["Date"])
            df.sort_values(by = "Date", inplace = True)
            
            try :
                start = df["Close"].iloc[0]
            except Exception as e:
                start = df["Close Price"].iloc[0]
            
            try :
                end = df["Close"].iloc[-1]
            except Exception as e:
                end = df["Close Price"].iloc[-1]
            gain = (end/start) - 1
            data[name] = gain
df = pd.DataFrame(data.items(), columns = ["security", "gain"])
df.sort_values(by = "gain", inplace = True, ascending = False)
df.head(10)
# Out:
#    security      gain
# 63   500126  3.478946
# 17   500034  2.134254
# 59   500120  2.079834
# 11   500027  1.216641
# 23   500043  1.157295
# 65   500133  1.112362
# 61   500124  1.077388
# 3    500009  0.828598
# 67   500136  0.794343
# 55   500114  0.736415

# %% [markdown]
# # 6. Identify the top 10 gainers (%) across groups over the last 3 years period

# %%
data = {}
for root,dirs,files in os.walk(os.curdir):
    for file in files:
        if file.endswith('.csv') and file.startswith("5"):
            name = os.path.splitext(file)[0]
            df = pd.read_csv(file, thousands = ",")
            df = df[0 : 3*365]
            df["Date"] = pd.to_datetime(df["Date"])
            df.sort_values(by = "Date", inplace = True)
            
            try :
                start = df["Close"].iloc[0]
            except Exception as e:
                start = df["Close Price"].iloc[0]
            
            try :
                end = df["Close"].iloc[-1]
            except Exception as e:
                end = df["Close Price"].iloc[-1]
            gain = (end/start) - 1
            data[name] = gain
df = pd.DataFrame(data.items(), columns = ["security", "gain"])
df.sort_values(by = "gain", inplace = True, ascending = False)
df.head(10)
# Out:
#    security      gain
# 63   500126  8.731702
# 59   500120  7.332085
# 26   500052  5.391608
# 5    500012  2.968379
# 55   500114  2.706121
# 36   500085  2.608696
# 11   500027  2.360292
# 31   500069  2.027523
# 65   500133  2.012141
# 99   500199  1.689524

# %% [markdown]
# # 7. Identify the top 10 gainers (%) across groups over the last 5 years period

# %%
data = {}
for root,dirs,files in os.walk(os.curdir):
    for file in files:
        if file.endswith('.csv') and file.startswith("5"):
            name = os.path.splitext(file)[0]
            df = pd.read_csv(file, thousands = ",")
            df = df[0 : 5*365]
            df["Date"] = pd.to_datetime(df["Date"])
            df.sort_values(by = "Date", inplace = True)
            
            try :
                start = df["Close"].iloc[0]
            except Exception as e:
                start = df["Close Price"].iloc[0]
            
            try :
                end = df["Close"].iloc[-1]
            except Exception as e:
                end = df["Close Price"].iloc[-1]
            gain = (end/start) - 1
            data[name] = gain
df = pd.DataFrame(data.items(), columns = ["security", "gain"])
df.sort_values(by = "gain", inplace = True, ascending = False)
df.head(10)
# Out:
#    security      gain
# 63   500126  7.770662
# 59   500120  6.584091
# 26   500052  4.462151
# 55   500114  3.437920
# 11   500027  3.026806
# 36   500085  2.841322
# 5    500012  2.380471
# 99   500199  2.367250
# 23   500043  2.128142
# 31   500069  2.027523

# %% [markdown]
# # TASK-2
# # Analysis

# %% [markdown]
# # Identify the stock most correlated with ICICI Bank's stockprice

# %%
icici_bank = "532174"
df_icici_bank = pd.read_csv(icici_bank + ".csv",thousands=",")

stock_corr = {}
for root,dirs,files in os.walk(os.curdir):
    for file in files:
        if file.endswith('.csv') and file.startswith("5"):
            name = os.path.splitext(file)[0]
            if name == icici_bank:
                continue
            df = pd.read_csv(file,thousands=",")
            cor = df_icici_bank["Total Turnover (Rs.)"].corr(df["Total Turnover (Rs.)"])
            stock_corr[name] = cor

icici_corr = pd.DataFrame(stock_corr.items(),columns=["security","correlation"])
icici_corr = icici_corr.sort_values(by="correlation",ascending=False)
icici_corr.head(1)
# Out:
#    security  correlation
# 53   500112     0.090095

# %% [markdown]
# # TASK-3
# # Visualization

# %% [markdown]
# # Draw a correlation matrix of any 30 stocks on the Sensex. This is a matrix with both axes holding the stock names.The colour of each cell is the correlation between that pair of stocks: blue for -1 and green for 1

# %%
dfs = {}
stock_names = set()
def read_dfs():
    for root,dirs,files in os.walk(os.curdir):
        for file in files:
            if len(stock_names) == 30:
                return
            if file.endswith('.csv') and file.startswith("5"):
                name = os.path.splitext(file)[0]
                df = pd.read_csv(file,thousands=",")
                dfs[name] = df
                stock_names.add(name)
read_dfs()

# %%
samp = pd.DataFrame(columns=stock_names,index=stock_names)
for n1,n2 in combinations(stock_names,2):
    df1 = dfs[n1]
    df2 = dfs[n2]
    c1 = df1["Total Turnover (Rs.)"].corr(df2["Total Turnover (Rs.)"])
    c2 = df2["Total Turnover (Rs.)"].corr(df1["Total Turnover (Rs.)"])
    samp.loc[n1,n2] = c1
    samp.loc[n2,n1] = c2
    samp.loc[n1,n1] = 1
    samp.loc[n2,n2] = 1
samp = samp.astype({name:"float" for name in stock_names})

# %%
samp.style.background_gradient(cmap="brg")
# Out:
# <style  type="text/css" >
# #T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow0_col0,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow1_col1,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow2_col2,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow3_col3,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow4_col4,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow5_col5,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow6_col6,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow7_col7,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow8_col8,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow9_col9,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow10_col10,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow11_col11,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow12_col12,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow13_col13,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow14_col14,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow15_col15,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow16_col16,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow17_col17,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow18_col18,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow19_col19,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow20_col20,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow21_col21,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow22_col22,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow23_col23,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow24_col24,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow25_col25,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow26_col26,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow27_col27,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow28_col28,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow29_col29{
#             background-color:  #00ff00;
#             color:  #000000;
#         }#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow0_col1,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow1_col28,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow5_col28,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow6_col4,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow9_col7,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow10_col15,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow10_col25,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow11_col13,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow13_col12,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow15_col4,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow16_col22,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow18_col22,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow20_col22,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow21_col5,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow25_col7,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow25_col15,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow26_col27,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow27_col22,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow28_col20{
#             background-color:  #1600e9;
#             color:  #f1f1f1;
#         }#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow0_col2,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow0_col17,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow0_col19,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow2_col0,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow9_col17,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow11_col0,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow12_col8,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow13_col20,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow15_col2,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow15_col26,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow19_col0,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow23_col14,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow25_col26,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow25_col27,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow26_col17{
#             background-color:  #4400bb;
#             color:  #f1f1f1;
#         }#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow0_col3,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow4_col2,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow4_col19,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow6_col5,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow7_col26,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow9_col0,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow12_col17,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow13_col6,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow13_col19,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow14_col3,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow17_col23,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow18_col9,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow20_col8,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow20_col21,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow23_col1,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow23_col29,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow25_col0,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow29_col16{
#             background-color:  #3600c9;
#             color:  #f1f1f1;
#         }#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow0_col4,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow2_col18,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow4_col16,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow7_col24,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow9_col25,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow9_col26,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow12_col3,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow14_col7,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow14_col25,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow17_col24,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow17_col28,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow18_col3,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow18_col14,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow22_col16,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow24_col14,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow24_col17,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow25_col11,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow26_col16,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow27_col16,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow28_col10{
#             background-color:  #2600d9;
#             color:  #f1f1f1;
#         }#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow0_col5,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow2_col15,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow7_col2,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow9_col14,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow9_col21,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow12_col22,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow14_col6,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow14_col23,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow17_col14,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow20_col0,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow21_col12,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow21_col15,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow22_col0,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow22_col6,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow22_col19,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow26_col4,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow28_col11,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow28_col16{
#             background-color:  #2800d7;
#             color:  #f1f1f1;
#         }#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow0_col6,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow3_col26,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow6_col0,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow6_col20,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow9_col11,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow13_col8,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow13_col26,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow14_col12,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow17_col2,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow19_col23,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow21_col0,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow21_col17,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow23_col8,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow25_col17{
#             background-color:  #5000af;
#             color:  #f1f1f1;
#         }#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow0_col7,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow3_col28,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow4_col20,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow9_col22,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow10_col7,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow11_col4,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow11_col25,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow12_col10,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow12_col16,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow16_col5,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow18_col23,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow21_col25,#T_7e292cdc_c07b_11eb_a1e0_80e82c6f147erow24_col23,#T_7e292cdc_c07b_11eb_a

# %% [markdown]
# # Draw a sparkline showing the data 23,80,92,62,98,7,9,56,19,68.

# %%
import base64
import io

def spark_line(data, figsize=(4, 0.25), **kwags):
    """
    Returns a HTML image tag containing a base64 encoded sparkline style plot
    """
    data = list(data)

    fig, ax = plt.subplots(1, 1, figsize=figsize, **kwags)
    ax.plot(data)
    for k,v in ax.spines.items():
        v.set_visible(False)
    ax.set_xticks([])
    ax.set_yticks([])

    plt.plot(len(data) - 1, data[len(data) - 1], 'r.')

    ax.fill_between(range(len(data)), data, len(data)*[min(data)], alpha=0.1)

    img = io.BytesIO()
    plt.savefig(img, transparent=True, bbox_inches='tight')
    img.seek(0)
    plt.close()

    return base64.b64encode(img.read()).decode("UTF-8")

# %%
values = [23,80,92,62,98,7,9,56,19,68]
#giving these values to plot.

with open("sparkline.html", "a") as file:
        file.write('<div><h1>Sparkline to the given values</h1></div>')
        file.write('<br>')
        file.write('<br>')
        file.write('<div><img src="data:image/png;base64,{}"/></div>'.format(spark_line(values)))
        file.write('<div></div>')

# %% [markdown]
# #  TASK-4

# %% [markdown]
# # For each stock, draw a sparkline showing last month's closing price trend

# %%
closing_prices = list()
for file in os.listdir():
    if file.endswith('.csv'):
        file_name = os.path.splitext(file)[0]
        if not file_name.isdecimal() :
            continue
        df = pd.read_csv(file,thousands=",")
        try:
            closing_prices.append(df["Close"][0: 30].values)
        except Exception as e:
            closing_prices.append(df["Close Price"][0: 30].values)

with open("bse_closing_price.html", "a") as file:
    file.write('<div><h1>Sparkline to the Closing Price values</h1></div>')
    file.write('<br>')
    file.write('<br>')
    for value in closing_prices:
        file.write('<div><img src="data:image/png;base64,{}"/></div>'.format(spark_line(value)))
        file.write('<div></div>')

# %% [markdown]
# # Convert these files into PDF without using a browser

# %%
client = pdfcrowd.HtmlToPdfClient('demo', 'ce544b6ea52a5621fb9d55f8b542d14d')
client.convertFileToFile('bse_closing_price.html', 'bse_closing_price.pdf')
